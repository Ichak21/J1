# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wine_dataset = pd.read_csv("winequalityN.csv")

# %% [markdown]
# # Analyse de la forme des données

# %%
print("Nb Colonnes : " + str(wine_dataset.shape[1])+ " | Nb Ligne : " + str(wine_dataset.shape[0]))
# Out:
# Nb Colonnes : 13 | Nb Ligne : 6497

# %%
print(wine_dataset.dtypes)
wine_dataset.dtypes.value_counts().plot.pie()
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
# <AxesSubplot:ylabel='None'>

# %%
wine_dataset["type"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='type'>

# %%
sns.heatmap(wine_dataset.isna())
# Out:
# <AxesSubplot:>

# %%
((wine_dataset.isna().sum()/wine_dataset.shape[0])*100).sort_values(ascending=False)
# Out:
# fixed acidity           0.153917
# pH                      0.138525
# volatile acidity        0.123134
# sulphates               0.061567
# citric acid             0.046175
# residual sugar          0.030783
# chlorides               0.030783
# type                    0.000000
# free sulfur dioxide     0.000000
# total sulfur dioxide    0.000000
# density                 0.000000
# alcohol                 0.000000
# quality                 0.000000
# dtype: float64

# %% [markdown]
# # Analyse des valeurs de données

# %%
print(wine_dataset["quality"].describe())

dist_red_quality = wine_dataset[wine_dataset['type'] == "red" ]["quality"]
sns.histplot(dist_red_quality, legend=True, color='red')

dist_white_quality = wine_dataset[wine_dataset['type'] == "white" ]["quality"]
sns.histplot(dist_white_quality, legend=True, color="white")
# Out:
# count    6497.000000
# mean        5.818378
# std         0.873255
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64
# <AxesSubplot:xlabel='quality', ylabel='Count'>

# %%
# Out:
#       fixed acidity  quality
# 4898            7.4        5
# 4899            7.8        5
# 4900            7.8        5
# 4902            7.4        5
# 4903            7.4        5
# ...             ...      ...
# 6480            6.1        5
# 6481            6.2        5
# 6487            6.6        5
# 6492            6.2        5
# 6495            5.9        5
#
# [681 rows x 2 columns]

# %%
for col in wine_dataset.select_dtypes('float'):
    for quality in wine_dataset["quality"].value_counts().index.sort_values():
        print(" ============= > Analyse de " + str(col) + " pour la qualité " + str(quality))
        plt.figure()
        sns.histplot(wine_dataset[(wine_dataset["type"]=="red") & (wine_dataset["quality"]==quality)][col], kde=True, color='red')
        sns.histplot(wine_dataset[(wine_dataset["type"]=="white") & (wine_dataset["quality"]==quality)][col], kde=True, color='white')
        plt.show()
# Out:
#  ============= > Analyse de fixed acidity pour la qualité 3
#  ============= > Analyse de fixed acidity pour la qualité 4
#  ============= > Analyse de fixed acidity pour la qualité 5
#  ============= > Analyse de fixed acidity pour la qualité 6
#  ============= > Analyse de fixed acidity pour la qualité 7
#  ============= > Analyse de fixed acidity pour la qualité 8
#  ============= > Analyse de fixed acidity pour la qualité 9
#  ============= > Analyse de volatile acidity pour la qualité 3
#  ============= > Analyse de volatile acidity pour la qualité 4
#  ============= > Analyse de volatile acidity pour la qualité 5
#  ============= > Analyse de volatile acidity pour la qualité 6
#  ============= > Analyse de volatile acidity pour la qualité 7
#  ============= > Analyse de volatile acidity pour la qualité 8
#  ============= > Analyse de volatile acidity pour la qualité 9
#  ============= > Analyse de citric acid pour la qualité 3
# ...

# %%
wine_dataset["quality"].value_counts().index.sort_values()
# Out:
# Int64Index([3, 4, 5, 6, 7, 8, 9], dtype='int64')
